# %% [markdown]
# # Sudoku Search for Training Data

# %%
import os
import uuid
import hashlib
import torch
import ray
from fastbook import *
from fastdownload import FastDownload

# %%
imageDir = "./search"

# %%
urls = search_images_ddg('sudoku', max_images=400)
len(urls),urls[0]
# Out:
# (400,
#  'https://i.pinimg.com/originals/de/a4/45/dea445849f7a9344ae3d4642cb228193.jpg')

# %%
def calculateMd5(filename):
    runningMd5 = hashlib.md5()
    with open(filename, "rb") as f:
        for chunk in iter(lambda: f.read(4096), b""):
            runningMd5.update(chunk)
    return runningMd5.hexdigest()

# %%
def doesContentAlreadyExist(filename, dir):
    newFileHash = calculateMd5(filename)

    for f in os.listdir(dir):
        absFile = os.path.join(dir, f)
        if os.path.isfile(absFile):
            hash = calculateMd5(absFile)
            if (hash == newFileHash):
                return True

    return False

# %%
d = FastDownload(base=imageDir, archive='downloaded', data='extracted')
for url in urls:
#    url = url.split('?')[0]
    print ("Processing URL: " + url)
    try:
        d.download(url)
    except HTTPError:
        print("Skipping url due to HTTP connection issue")
    except URLError:
        print("Skipping url due to a malformed URL issue of some type")

#    e = re.findall('\.[a-z]+$', url)
#    if (len(e)) == 1:
#        fileExtension = e[0]
#        randomName = str(uuid.uuid4().hex)
#        filename = randomName + fileExtension
#        tempFilename = "/tmp/" + filename
        
#        download_url(url, tempFilename)

#        if doesContentAlreadyExist(tempFilename, imageDir) == True:
#            print ("Found: " + tempFilename)
#            os.remove(tempFilename)
#        else:
#            print ("NEW: " + tempFilename)
#            os.replace(tempFilename, imageDir + "/" + filename)

#    else:
#        print ("Unable to process image due to unexpected extension: " + e + " with URL: " + url)
# Out:
# Processing URL: https://i.pinimg.com/originals/de/a4/45/dea445849f7a9344ae3d4642cb228193.jpg
# Processing URL: https://www.freepdfmagazine.com/puzzlelife-puzzlepad-sudoku-super-november-2023/PuzzleLife-PuzzlePad-Sudoku-Super-November-2023.jpg
# Processing URL: https://printablesudokufree.com/wp-content/uploads/2019/05/sudoku-printable-free-medium-printable-sudoku-puzzle-1-my-printable-alphabet-sudoku.jpg
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8192' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -819200.00% [8192/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='16384' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -1638400.00% [16384/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='24576' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -2457600.00% [24576/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='32768' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -3276800.00% [32768/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='40960' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -4096000.00% [40960/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='49152' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -4915200.00% [49152/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='57344' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -5734400.00% [57344/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='65536' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -6553600.00% [65536/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='73728' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -7372800.00% [73728/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='81920' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -8192000.00% [81920/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='90112' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -9011200.00% [90112/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='98304' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -9830400.00% [98304/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='106496' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -10649600.00% [106496/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='114688' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -11468800.00% [114688/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='122880' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -12288000.00% [122880/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='131072' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -13107200.00% [131072/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='139264' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -13926400.00% [139264/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='147456' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -14745600.00% [147456/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='155648' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -15564800.00% [155648/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='163840' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -16384000.00% [163840/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='172032' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -17203200.00% [172032/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='180224' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -18022400.00% [180224/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='188416' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -18841600.00% [188416/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='196608' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -19660800.00% [196608/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='204800' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -20480000.00% [204800/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='212992' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -21299200.00% [212992/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='221184' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -22118400.00% [221184/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='229376' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -22937600.00% [229376/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='237568' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -23756800.00% [237568/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='245760' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -24576000.00% [245760/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='253952' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -25395200.00% [253952/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='262144' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -26214400.00% [262144/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='270336' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -27033600.00% [270336/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='278528' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -27852800.00% [278528/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='286720' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -28672000.00% [286720/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='294912' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -29491200.00% [294912/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='303104' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -30310400.00% [303104/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='311296' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -31129600.00% [311296/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='319488' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -31948800.00% [319488/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='327680' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -32768000.00% [327680/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='335872' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -33587200.00% [335872/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='344064' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -34406400.00% [344064/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='352256' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -35225600.00% [352256/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='360448' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -36044800.00% [360448/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='368640' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -36864000.00% [368640/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='376832' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -37683200.00% [376832/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='385024' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -38502400.00% [385024/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='393216' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -39321600.00% [393216/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='401408' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -40140800.00% [401408/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='409600' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -40960000.00% [409600/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='417792' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -41779200.00% [417792/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='425984' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -42598400.00% [425984/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='434176' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -43417600.00% [434176/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='442368' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -44236800.00% [442368/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='450560' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -45056000.00% [450560/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='458752' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -45875200.00% [458752/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='466944' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -46694400.00% [466944/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='475136' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -47513600.00% [475136/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='483328' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -48332800.00% [483328/-1 00:00&lt;00:00]
#     </div>
# Processing URL: https://images.sftcdn.net/images/t_app-cover-l,f_auto/p/5e11ba97-dcff-4606-8f1e-9ff421ca40e8/1797858587/sudoku-magic-the-puzzle-game-screenshot.png
# Processing URL: https://2.bp.blogspot.com/-3ZKRPPnHE1M/Tj7xWYqoBiI/AAAAAAAAELc/1vCdgiKLHW0/s1600/100-sudoku-facil_Page_010-764762.jpg
# Processing URL: https://printable-crosswordpuzzles.com/wp-content/uploads/2019/06/about-printable-sudoku-puzzlesprintable-sudoku-puzzle-77-tory-printable-sudoku-puzzles-16x16-free.png
# Processing URL: https://kinderbilder.download/wp-content/uploads/2020/06/sudoku-online-losen-mit-dem-sudoku-solver-fur-sudoku-zum-ausdrucken-sehr-schwer-scaled.jpg
# Processing URL: http://www.memory-improvement-tips.com/images/sudoku-hard-7-1.jpg
# Processing URL: https://img4.fresherslive.com/latestnews/2023/12/nyt-sudoku-hard-puzzle-today-11-december-2023-65768de67dff159025652-1200.webp
# Processing URL: http://2.bp.blogspot.com/-VZJpz8N80eM/UUsyiVV8KxI/AAAAAAAAAFg/--f_XKI57o8/s1600/TEST_SUDOKU.jpg
# Processing URL: https://free-printablehq.com/wp-content/uploads/2019/07/printable-sudoku-samurai-give-these-puzzles-a-try-and-youll-be-free-printable-sudoku-6-per-page-809x1024.jpg
# Processing URL: http://www.gamesavenue.net/gallery/mathematics-puzzle-games/sudoku_puzzle_game-copy.jpg
# Skipping url due to a malformed URL issue of some type
# Processing URL: https://i.pinimg.com/originals/91/32/68/91326804e2f4ea58ebb49efd6c64429d.jpg
# Processing URL: https://images.sftcdn.net/images/t_app-cover-l,f_auto/p/dff6c036-9b27-11e6-a9ba-00163ed833e7/2675625261/ahr-sudoku-screenshot.jpg
# Processing URL: https://shepherdexpress.com/downloads/63815/download/Sudoku_12072023.jpg?cb=13dd9d6cc60eea421112ff207e2f1746&w=%7Bwidth%7D&h=%7Bheight%7D
# Processing URL: https://i.pinimg.com/736x/96/fa/e7/96fae7e35a7443a344dd6e7e993075fd.jpg
# Processing URL: https://sudokuprintables.com/wp-content/uploads/2020/04/hard-sudoku-printable-6-per-page-printabler-38.jpg
# Processing URL: https://sudoku-club.de/wp-content/uploads/2017/01/sudoku.png
# Processing URL: http://www.sudokuweb.org/wp-content/uploads/2013/05/sudoku-kids-6x6-14.png
# Processing URL: https://preview.redd.it/this-is-the-hardest-easy-sudoku-ive-ever-seen-v0-6e6pdud7w05c1.jpeg?width=1080&crop=smart&auto=webp&s=30a86e2b550cf889467aa5166c9fe8c5108ca019
# Processing URL: http://thetripclip.com/tc/images/pins/sudoku-for-all-ages-4x4-6x6-9x9.png
# ...
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='868352' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -86835200.00% [868352/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='876544' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -87654400.00% [876544/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='884736' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -88473600.00% [884736/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='892928' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -89292800.00% [892928/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='901120' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -90112000.00% [901120/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='909312' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -90931200.00% [909312/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='917504' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -91750400.00% [917504/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='925696' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -92569600.00% [925696/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='933888' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -93388800.00% [933888/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='942080' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -94208000.00% [942080/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='950272' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -95027200.00% [950272/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='958464' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -95846400.00% [958464/-1 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='966656' class='' max='-1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       -96665600.00% [966656/-1 00:00&lt;00:00]
#     </div>
# Processing URL: http://www.activityshelter.com/wp-content/uploads/2017/04/soduko-for-kids-6x6.jpg
# Processing URL: https://kinderbilder.download/wp-content/uploads/2020/06/kombinatorik-ein-sudoku-benotigt-mindestens-17-vorgaben-bestimmt-fur-sudoku-kostenlos-drucken-schwer.jpg
# Processing URL: http://www.memory-improvement-tips.com/images/hard-1b-2.jpg
# Processing URL: https://printablesudokufree.com/wp-content/uploads/2019/05/printable-sudoku-puzzles-room-surf-printable-sudoku-answer-sheet.jpg
# Processing URL: https://images.sftcdn.net/images/t_app-cover-m,f_auto/p/2d62cc22-96d5-11e6-8934-00163ed833e7/3836074902/simple-sudoku-screenshot.jpg
# Processing URL: https://sudokuprintables.com/wp-content/uploads/2020/03/printable-medium-sudoku-https-www-dadsworksheets-46.jpg
# Processing URL: http://1.bp.blogspot.com/_Kh0CZuWd0T8/Sn_2xz3sI1I/AAAAAAAAFE4/Op3LPqF48RY/s400/PRINTABLE+SUDOKU+PUZZLES+(6).gif
# Processing URL: https://i.pinimg.com/originals/5c/be/c3/5cbec304dabf40b449f3047e9176d414.png
# Processing URL: https://i.pinimg.com/originals/c8/61/f3/c861f318993d93f3e7a87c01ca777b55.png
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='32768' class='' max='26593' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       123.22% [32768/26593 00:00&lt;00:00]
#     </div>
# Processing URL: https://images.sftcdn.net/images/t_app-cover-l,f_auto/p/c3d82947-6e12-4605-85db-96572cebff11/4198512865/sudoku-game-unlimited-screenshot.png
# Processing URL: https://www.puzz.com/sudoku10p.png
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8192' class='' max='3877' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       211.30% [8192/3877 00:00&lt;00:00]
#     </div>
# Processing URL: http://photos1.blogger.com/blogger/546/1536/1024/500sudokus-acrobat_Page_009.jpg
# Processing URL: https://3.bp.blogspot.com/-ggiGD61URG0/Tj7qXsjIj_I/AAAAAAAAEKE/AXYlw0w7YGc/s1600/100-sudoku-facil_Page_001.jpg
# Processing URL: https://baileyspuzzles.com/wp-content/uploads/2020/10/how-to-play-sudoku-1.png
# Processing URL: https://www.dadsworksheets.com/puzzles/sudoku/sudoku-samuari-five-1-v1.jpg
# Processing URL: https://imag.malavida.com/mvimgbig/download-fs/andoku-sudoku-2-28273-10.jpg
# Processing URL: http://3.bp.blogspot.com/_Kh0CZuWd0T8/Sn_134cGAPI/AAAAAAAAFEQ/ibFKcyl2goE/w1200-h630-p-k-no-nu/PRINTABLE+SUDOKU+PUZZLES+(2).jpg
# Processing URL: http://allfreeprintable.com/cont/sdku/img/free-printable-easy-sudoku-puzzles.jpg
# Processing URL: https://kinderbilder.download/wp-content/uploads/2020/06/kombinatorik-ein-sudoku-benotigt-mindestens-17-vorgaben-bestimmt-fur-sudoku-kostenlos-drucken-schwer-1536x864.jpg
# Processing URL: https://printablesudokufree.com/wp-content/uploads/2019/05/printable-hard-sudoku-printable-difficult-sudoku-puzzles-printable-sudoku-variations.jpg
# Processing URL: https://printable-crosswordpuzzles.com/wp-content/uploads/2019/06/sudoku-puzzler-free-printable-updated-sudoku-puzzles-with-a-printable-sudoku-puzzles-easy-1.jpg
# Processing URL: https://mysteriouswritings.com/wp-content/uploads/2016/12/364px-Sudoku-by-L2G-20050714.svg_.png
# Processing URL: http://photos1.blogger.com/blogger/7180/2224/1600/Sudoku_001.jpg
# Processing URL: https://image.winudf.com/v2/image/Y29tLnRnYW1lcy5qdWVnb3N1ZG9rdV9zY3JlZW5zaG90c18xX2JlNWMzYmEz/screen-1.jpg?fakeurl=1&type=.jpg
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='106496' class='' max='100533' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       105.93% [106496/100533 00:00&lt;00:00]
#     </div>
# Processing URL: https://sudokuprintables.com/wp-content/uploads/2020/04/the-best-printable-blank-sudoku-4-per-page-dans-blog-2.jpg
# Processing URL: https://blogs-images.forbes.com/erikaandersen/files/2013/03/300px-Sudoku-by-L2G-20050714.svg_1.png
# Processing URL: https://uploads.guim.co.uk/2020/03/31/Sudoku_4771_easy.jpg
# Processing URL: https://www.bestsevenreviews.com/wp-content/uploads/2019/12/sudoku-kingdom.jpg
# Processing URL: https://printablesudokufree.com/wp-content/uploads/2019/05/sudoku-of-the-day-daily-puzzles-tricks-and-tips-sudoku-today-printable.png
# Processing URL: https://www.carlosag.net/games/Sudoku.png
# Processing URL: https://media.istockphoto.com/vectors/sudoku-vector-id1042746564
# Processing URL: https://printablesudokufree.com/wp-content/uploads/2019/05/easy-printable-sudoku-rtrs-online-printable-sudoku-easy-6x6-791x1024.jpg
# Processing URL: https://1.bp.blogspot.com/-42iqzsytI6g/UN0EUjT3esI/AAAAAAAABxE/P6b1Gj_jsGI/s1600/Sudoku_template.PNG
# Processing URL: https://sudokuprintables.com/wp-content/uploads/2020/04/free-easy-sudoku-puzzle-05-sudoku-puzzler-4.jpg

# %%
ds = ray.data.read_images(imageDir)
print ("Number of records: " + str(ds.count()))
print ("Size of data set: " + str(ds.size_bytes()) + " bytes")
# Out:
# 2023-12-11 17:05:40,210	ERROR services.py:1169 -- Failed to start the dashboard , return code 0
# 2023-12-11 17:05:40,211	ERROR services.py:1194 -- Error should be written to 'dashboard.log' or 'dashboard.err'. We are printing the last 20 lines for you. See 'https://docs.ray.io/en/master/ray-observability/ray-logging.html#logging-directory-structure' to find where the log file is.
# 2023-12-11 17:05:40,215	ERROR services.py:1238 --
# The last 20 lines of /tmp/ray/session_2023-12-11_17-05-38_084069_70917/logs/dashboard.log (it contains the error message from the dashboard):
#     loop.run_until_complete(dashboard.run())
#   File "/Users/lroland/anaconda3/envs/sudoku-ai/lib/python3.10/asyncio/base_events.py", line 641, in run_until_complete
#     return future.result()
#   File "/Users/lroland/anaconda3/envs/sudoku-ai/lib/python3.10/site-packages/ray/dashboard/dashboard.py", line 70, in run
#     await self.dashboard_head.run()
#   File "/Users/lroland/anaconda3/envs/sudoku-ai/lib/python3.10/site-packages/ray/dashboard/head.py", line 302, in run
#     self.http_server = await self._configure_http_server(modules)
#   File "/Users/lroland/anaconda3/envs/sudoku-ai/lib/python3.10/site-packages/ray/dashboard/head.py", line 143, in _configure_http_server
#     http_server = HttpServerDashboardHead(
#   File "/Users/lroland/anaconda3/envs/sudoku-ai/lib/python3.10/site-packages/ray/dashboard/http_server_head.py", line 93, in __init__
#     raise ex
#   File "/Users/lroland/anaconda3/envs/sudoku-ai/lib/python3.10/site-packages/ray/dashboard/http_server_head.py", line 84, in __init__
#     build_dir = setup_static_dir()
#   File "/Users/lroland/anaconda3/envs/sudoku-ai/lib/python3.10/site-packages/ray/dashboard/http_server_head.py", line 42, in setup_static_dir
#     raise dashboard_utils.FrontendNotFoundError(
# ray.dashboard.utils.FrontendNotFoundError: [Errno 2] Dashboard build directory not found. If installing from source, please follow the additional steps required to build the dashboard(cd python/ray/dashboard/client && npm ci && npm run build): '/Users/lroland/anaconda3/envs/sudoku-ai/lib/python3.10/site-packages/ray/dashboard/client/build'
#
# 2023-12-11 17:05:40,139	ERROR base_events.py:1729 -- Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10ec7a560>
# 2023-12-11 17:05:40,139	ERROR base_events.py:1729 -- Unclosed client session
# 2023-12-11 17:05:40,351	INFO worker.py:1553 -- Started a local Ray instance.
# Number of records: 485
# Size of data set: 95758046 bytes
